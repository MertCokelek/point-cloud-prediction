# %%
import os
path = "/home/mcokelek21/Workstation/Desktop/KITTI_odometry/dataset/sequences/00/processed.bin"
os.path.basename(path)
# Out:
# 'processed.bin'

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
intensity = np.load(f"{path}/intensity/000001.npy")
intensity.shape
# Out:
# (64, 2048)

# %%
range_img = np.load(f"{path}/range/000001.npy")
range_img.shape
# Out:
# (64, 2048)

# %%
xyz = np.load(f"{path}/xyz/000001.npy")
xyz.shape
# Out:
# (64, 2048, 4)

# %%
def imshow(s):
    plt.figure(figsize=(80, 4))
    plt.imshow(s)
    plt.xticks([])
    plt.yticks([])
    plt.show()
imshow(intensity)
imshow(range_img)
imshow(xyz[..., :3])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
